# %%
def rock_paper_scissor(num1, num2, bit1, bit2):
    # Check if bit1 and bit2 are within the valid range of indices for num1 and num2
    if bit1 >= len(num1) or bit2 >= len(num2):
        print("Invalid bit position! Please enter valid bit positions.")
        return

    # Calculate the index for player one's choice using the secret bit position
    p1 = int(num1[bit1]) % 3
    # Calculate the index for player two's choice using the secret bit position
    p2 = int(num2[bit2]) % 3

    # Check if both players chose the same option
    if player_one[p1] == player_two[p2]:
        print("Draw")
    # Check if player one chose Rock and player two chose Scissor
    elif player_one[p1] == "Rock" and player_two[p2] == "Scissor":
        print("Player one wins!!")
    # Check if player one chose Rock and player two chose Paper
    elif player_one[p1] == "Rock" and player_two[p2] == "Paper":
        print("Player two wins!!")
    # Check if player one chose Paper and player two chose Scissor
    elif player_one[p1] == "Paper" and player_two[p2] == "Scissor":
        print("Player two wins!!")
    # Check if player one chose Paper and player two chose Rock
    elif player_one[p1] == "Paper" and player_two[p2] == "Rock":
        print("Player one wins!!")
    # Check if player one chose Scissor and player two chose Rock
    elif player_one[p1] == "Scissor" and player_two[p2] == "Rock":
        print("Player two wins!!")
    # Check if player one chose Scissor and player two chose Paper
    elif player_one[p1] == "Scissor" and player_two[p2] == "Paper":
        print("Player one wins!!")

# Dictionary for player one's choices
player_one = {0: 'Rock', 1: 'Paper', 2: 'Scissor'}
# Dictionary for player two's choices
player_two = {0: 'Paper', 1: 'Rock', 2: 'Scissor'}

# Main game loop
while True:
    # Get player one's choice
    num1 = input("Player one, enter your choice (a string of numbers): ")
    # Get player two's choice
    num2 = input("Player two, enter your choice (a string of numbers): ")
    # Get player one's secret bit position
    bit1 = int(input("Player one, enter the secret bit position (0-based index): "))
    # Get player two's secret bit position
    bit2 = int(input("Player two, enter the secret bit position (0-based index): "))
    
    # Call the function to determine the winner
    rock_paper_scissor(num1, num2, bit1, bit2)
    
    # Ask if players want to continue
    ch = input("Do you want to continue? y/n: ")
    # Break the loop if players choose not to continue
    if ch == 'n':
        break
